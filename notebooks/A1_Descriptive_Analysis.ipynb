# %% [markdown]
# <div style="font-size:18pt; padding-top:20px; text-align:center">ЗАДАНИЕ. <b>Дескриптивный анализ данных</b> </div><hr>
# <div style="text-align:right;">Папулин С.Ю. <span style="font-style: italic;font-weight: bold;">(papulin.study@yandex.ru)</span></div>

# %% [markdown]
# <a name="0"></a>
# <div><span style="font-size:14pt; font-weight:bold">Содержание</span>
#     <ol>
#         <li><a href="#1">Варианты</a></li>
#         <li><a href="#2">Задание</a></li>
#     </ol>
# </div>

# %% [markdown]
# <p>Подключение стилей оформления</p>

# %%
# %%html
# <link href="css/style.css" rel="stylesheet" type="text/css">
# Out:
# <link href="css/style.css" rel="stylesheet" type="text/css">

# %% [markdown]
# <a name="1"></a>
# <div style="display:table; width:100%; padding-top:10px; padding-bottom:10px; border-bottom:1px solid lightgrey">
#     <div style="display:table-row">
#         <div style="display:table-cell; width:80%; font-size:14pt; font-weight:bold">1. Варианты</div>
#     	<div style="display:table-cell; width:20%; text-align:center; background-color:whitesmoke; border:1px solid lightgrey"><a href="#0">К содержанию</a></div>
#     </div>
# </div>

# %% [markdown]
# <p>Чтобы узнать свой вариант, введите Вашу фамилию в соответвующее поле ниже и запустите ячейку:</p>

# %%
surname = "Усошин"  # Ваша фамилия

alp = 'абвгдеёжзийклмнопрстуфхцчшщъыьэюя'
w = [1, 42, 21, 21, 34,  6, 44, 26, 18, 44, 38, 26, 14, 43,  4, 49, 45,
        7, 42, 29,  4,  9, 36, 34, 31, 29,  5, 30,  4, 19, 28, 25, 33]

d = dict(zip(alp, w))
variant =  sum([d[el] for el in surname.lower()]) % 40 + 1

print("Задача № 1, шаг 5 - вариант: ", variant % 5 + 1)
print("Задача № 1, шаг 11 - вариант: ", variant % 2 + 1 )
print("задача № 2 - вариант: ", variant % 4 + 1)
# Out:
# Задача № 1, шаг 5 - вариант:  4
# Задача № 1, шаг 11 - вариант:  2
# задача № 2 - вариант:  2

# %% [markdown]
# <div class="msg-block msg-warning">
#   <p class="msg-text-warn">Варианты могут не совпадать с последующими ДЗ</p>
# </div>

# %% [markdown]
# <a name="2"></a>
# <div style="display:table; width:100%; padding-top:10px; padding-bottom:10px; border-bottom:1px solid lightgrey">
#     <div style="display:table-row">
#         <div style="display:table-cell; width:80%; font-size:14pt; font-weight:bold">2. Задание</div>
#     	<div style="display:table-cell; width:20%; text-align:center; background-color:whitesmoke; border:1px solid lightgrey"><a href="#0">К содержанию</a></div>
#     </div>
# </div>

# %% [markdown]
# <div class="msg-block msg-imp">
#   <div class="msg-text-imp">
#       <p>СРОК СДАЧИ: до <b>-</b></p>
#       <p style="margin:0px">ПОСЛЕ СРОКА: первая неделя <b>-</b>, вторая неделя и далее до конца модуля <b>-</b>, потом <b>- баллов</b>
#       </p>
#   </div>
# </div>

# %% [markdown]
# <p><b>Задача 1.</b> Анализ индекса восприятия коррупции (Corruption Perceptions Index, CPI) (6 баллов)</p>

# %% [markdown]
# <p>1. Подключите библиотеки numpy, pandas, matplotlib</p>

# %%
# Ваш код
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <p>2. Загрузите данные из "data/CPI2020.xlsx" в DataFrame. Исходные данные и пояснения можно найти <a href="https://www.transparency.org/en/cpi/2020/index">здесь</a></p>

# %%
# Ваш код
cpiRanking = pd.read_csv('CPI2012-2020.csv') # В Excel сохранил таблицу как csv, заменил точку с запятой на запятую, а запятые на точки
df.head(5)
# Out:
#        Country ISO3 Region  CPI score 2020  Rank 2020  Sources 2020  \
# 0      Denmark  DNK  WE/EU              88          1             8
# 1  New Zealand  NZL     AP              88          1             8
# 2      Finland  FIN  WE/EU              85          3             8
# 3    Singapore  SGP     AP              85          3             9
# 4       Sweden  SWE  WE/EU              85          3             8
#
#    Standard error 2020  CPI score 2019  Rank 2019  Sources 2019  ...  \
# 0                 1.78              87          1             8  ...
# 1                 1.48              87          1             8  ...
# 2                 1.75              86          3             8  ...
# 3                 1.20              85          4             9  ...
# 4                 1.30              85          4             8  ...
#
#    Standard error 2015  CPI score 2014  Sources 2014  Standard error 2014  \
# ...

# %% [markdown]
# <p>3. Отсортируйте данные по убыванию индекса DataFrame</p>

# %%
# Ваш код
sortInv = cpiRanking.sort_index(ascending = 0) # Сортировка по убыванию индекса
sortInv.head(5)
# Out:
#          Country ISO3 Region  CPI score 2020  Rank 2020  Sources 2020  \
# 179  South Sudan  SSD    SSA              12        179             5
# 178      Somalia  SOM    SSA              12        179             6
# 177        Syria  SYR   MENA              14        178             5
# 176        Yemen  YEM   MENA              15        176             7
# 175    Venezuela  VEN    AME              15        176             8
#
#      Standard error 2020  CPI score 2019  Rank 2019  Sources 2019  ...  \
# 179                 1.11              12        179             5  ...
# 178                 2.29               9        180             5  ...
# 177                 1.58              13        178             5  ...
# 176                 1.33              15        177             7  ...
# 175                 0.91              16        173             8  ...
#
#      Standard error 2015  CPI score 2014  Sources 2014  Standard error 2014  \
# ...

# %% [markdown]
# <div><p>4. Отобразите данные по индексу CPI за 2020 год в виде горизонтального столбчатого графика. Примерный вид графика приведен ниже</p>
# <img src="img/cpi_2016_.png"></div>

# %%
# Ваш код

sortInv['RankCountry'] = sortInv["Rank 2020"].astype(str) +". "+ sortInv["Country"]
cpi = sortInv[['RankCountry','CPI score 2020']]
cpi.plot.barh(x ='RankCountry',y='CPI score 2020',grid = True, figsize=(3.5,50 ), legend = False)
plt.tick_params(bottom=False, top=True, left=True, right=False)
plt.tick_params(labelbottom=False, labeltop=True, labelleft=True, labelright=False)
plt.show()

# %% [markdown]
# <p>5. Сформируйте DataFrame из исходного для региона в соответствии с Вашим вариантом</p>
# <p><b>Вариант 1.</b> Asia Pacific</p>
# <p><b>Вариант 2.</b> Americas</p>
# <p><b>Вариант 3.</b> Europe and Central Asia</p>
# <p><b>Вариант 4.</b> Middle East and North Africa</p>
# <p><b>Вариант 5.</b> Sub Saharan Africa</p>

# %%
# Ваш код MENA
regCPI = cpiRanking[cpiRanking["Region"]=="MENA"]

# %% [markdown]
# <p>6. Выведите данные DataFrame'a</p>

# %%
# Ваш код
regCPI
# Out:
#                   Country ISO3 Region  CPI score 2020  Rank 2020  \
# 20   United Arab Emirates  ARE   MENA              71         21
# 30                  Qatar  QAT   MENA              63         30
# 36                 Israel  ISR   MENA              60         35
# 49                   Oman  OMN   MENA              54         49
# 55           Saudi Arabia  SAU   MENA              53         52
# 60                 Jordan  JOR   MENA              49         60
# 73                Tunisia  TUN   MENA              44         69
# 78                Bahrain  BHR   MENA              42         78
# 80                 Kuwait  KWT   MENA              42         78
# 87                Morocco  MAR   MENA              40         86
# 104               Algeria  DZA   MENA              36        104
# 116                 Egypt  EGY   MENA              33        117
# 150                  Iran  IRN   MENA              25        149
# ...

# %% [markdown]
# <div><p>7. Постройте графики индекса CPI за 2012-2020 для стран своего региона. Примерный вид графика приведен ниже</p>
# <img src="img/fig_springfield_region.png">
# </div>

# %%
# Ваш код
columns = ["CPI Score 2012", 
           "CPI Score 2013",
           "CPI score 2014",
           "CPI score 2015",
           "CPI score 2016",
           "CPI score 2017",
           "CPI score 2018",
           "CPI score 2019",
           "CPI score 2020"]
CPIregScore = regCPI[columns]
CPIregScore.T.plot(figsize=(15,5), legend = False, marker="o", grid = True, title = "Springfield", color = 'lightgrey')
ax = plt.subplot()
ax.set_ylabel('CPI')
plt.show()

# %% [markdown]
# <p>8. Найдите страны с наибольшим и наименьшим значением CPI Вашего варианта региона за 2020 год</p>

# %%
# Ваш код
CountryMax = regCPI['Country'][regCPI['CPI score 2020'].idxmax()]
CountryMin = regCPI['Country'][regCPI['CPI score 2020'].idxmin()]
print("Страна с наибольшим CPI MENA: ", CountryMax,"\nСтрана с наименьшим CPI MENA: ", CountryMin)
# Out:
# Страна с наибольшим CPI MENA:  United Arab Emirates
# Страна с наименьшим CPI MENA:  Syria

# %% [markdown]
# <p>9. Определите средние значения за каждый год в период с 2012 по 2020</p>

# %%
# Ваш код
Mean = CPIregScore.mean(0)
Mean
# Out:
# CPI Score 2012    40.000000
# CPI Score 2013    38.444444
# CPI score 2014    39.666667
# CPI score 2015    40.055556
# CPI score 2016    37.500000
# CPI score 2017    37.888889
# CPI score 2018    38.555556
# CPI score 2019    39.000000
# CPI score 2020    39.111111
# dtype: float64

# %% [markdown]
# <div><p>10. Постройте графики индекса CPI за 2012-2020 для стран своего региона и выделите страны с наибольшим и наименьшим значением CPI за 2020 год, а также отобразите среднее значение по региону и РФ. Примерный вид графика приведен ниже</p>
# <img src="img/fig_springfield_region_comb.png">
# </div>

# %%
# Ваш код
Min = regCPI[regCPI["Country"] == CountryMin]
Min = Min[columns]

Max = regCPI[regCPI["Country"] == CountryMax]
Max = Max[columns]

Russia = cpiRanking[cpiRanking["Country"] == 'Russia']
Russia = Russia[columns]

Springfield = CPIregScore.T.plot(figsize=(15,5), grid = True, title = "Springfield", linewidth = 2, legend = False, marker="o", color = 'lightgrey')

MinGraph = Min.T.plot( linewidth = 2, marker="o", grid = True, color = 'green',   ax = Springfield, label = "1")

MaxGraph = Max.T.plot( linewidth = 2, marker="o", grid = True, color = 'red',     ax = Springfield, label = "2")

RussiaGraph = Russia.T.plot( linewidth = 2, marker="o", grid = True, color = 'orange',  ax = Springfield, label = "3")

MeanGraph = Mean.T.plot( linewidth = 2, marker="o", grid = True, color = 'blue',    ax = Springfield, label = "4")

plt.legend(handles=[MinGraph,MaxGraph,RussiaGraph,MeanGraph,Springfield],loc='center left', bbox_to_anchor=(1, 0.5))
ax = plt.subplot()
ax.set_ylabel('CPI')
plt.show()
# Out:
# C:\Users\usoshin\AppData\Local\Temp/ipykernel_8640/2872891990.py:21: UserWarning: Legend does not support <AxesSubplot:title={'center':'Springfield'}> instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend(handles=[MinGraph,MaxGraph,RussiaGraph,MeanGraph,Springfield],loc='center left', bbox_to_anchor=(1, 0.5))

# %% [markdown]
# <p>11. Определите, как изменилось значение показателя в соответствии с Вашим вариантом с 2012 по 2020</p>
# <p><b>Вариант 1.</b> На сколько позиций в рейтинге c 2012 по 2020</p>
# <p><b>Вариант 2.</b> На сколько процентов значение CPI с 2012 по 2020</p>

# %% [markdown]
# <div class="msg-block msg-info">
#   <p class="msg-text-info">У нескольких стран может быть одна и та же позиция в рейтинге из-за одинаковых значений индекса</p>
# </div>

# %% [markdown]
# <p>12. Выведите </p>

# %%
import pandas as pnd

index = ["mean_2020", "max_2020", "min_2020", "Russia_2020"]
columns = ["Region", "Country", "Score 2012", "Score 2020", "Change in Position"]

# %%
columns = ["Region", "Country", "Score 2012", "Score 2020", "Change in Position"]
df = pnd.DataFrame(index=index, columns=columns)
df
# Out:
#             Region Country Score 2012 Score 2020 Change in Position
# mean_2020      NaN     NaN        NaN        NaN                NaN
# max_2020       NaN     NaN        NaN        NaN                NaN
# min_2020       NaN     NaN        NaN        NaN                NaN
# Russia_2020    NaN     NaN        NaN        NaN                NaN

# %%
columns = ["Region", "Country", "Score 2012", "Score 2020", "Change in %"]
df = pnd.DataFrame(index=index, columns=columns)
df
# Out:
#             Region Country Score 2012 Score 2020 Change in %
# mean_2020      NaN     NaN        NaN        NaN         NaN
# max_2020       NaN     NaN        NaN        NaN         NaN
# min_2020       NaN     NaN        NaN        NaN         NaN
# Russia_2020    NaN     NaN        NaN        NaN         NaN

# %%
# Ваш код

# %% [markdown]
# <p><b>Задача 2.</b> Анализ рынка акций (4 балла)</p>

# %% [markdown]
# <p>1. Загрузите данные в один dataframe из всех файлов в папке /data/stock. Все файлы имеют одинаковую структуру, в том числе наименование столбцов. В качестве значений индекса dataframe'а необходимо указать значения столбца "Date". Название столбцов должные соответствовать названию акций (имя файла без .csv), а их значения - значениям цены закрытия (столбец "Close" в файлах .csv)</p>

# %%
# Ваш код
# import os
# os.listdir(file_path) - список файлов в папке file_path
# pnd.read_csv(full_file_name, index_col=0, parse_dates=True) - загрузка из файла в dataframe
# dfStock["Close"] - нужна только цена закрытия

# %% [markdown]
# <p>2. Рассчитайте корреляционную матрицу для всех акций</p>

# %%
# Ваш код

# %% [markdown]
# <p>3. Отобразите корреляционную матрицу в виде диаграммы. Примерный вид графика приведен ниже</p>
# <img src="img/fig_corr_matrix.png" width="400px">

# %%
# Ваш код
# matshow(corrMatrix, vmin=-1, vmax=1)

# %% [markdown]
# <div>
# <p>4. В соответствии с Вашим вариантом определите:</p>
# <ul>
#     <li>акцию с максимальной корреляцией (max)</li>
#     <li>акцию с минимальной корреляцией (min) </li>
#     <li>акцию, которая больше всего соответствует отсутствию какой-либо корреляции (none)</li>
# </ul>
# </div>

# %% [markdown]
# <p><b>Вариант 1.</b> Microsoft (MSFT)</p>
# <p><b>Вариант 2.</b> Facebook (FB)</p>
# <p><b>Вариант 3.</b> Google (GOOGL)</p>
# <p><b>Вариант 4.</b> Alibaba (BABA)</p>

# %%
# Ваш код

# %% [markdown]
# <p>5. Постройте диаграммы разброса (Ваша компания - Компания с min), (Ваша компания - Компания с max), (Ваша компания - Компания с none)</p>

# %%
# Ваш код
# scatter

# %% [markdown]
# <p>6. Рассчитайте среднюю цену акций для каждого месяца (исходные данные взяты с интервалом в месяц)</p>

# %%
# Ваш код

# %% [markdown]
# <p>7. Постройте графики для акций из пункта 4 и средней из пункта 6. Примерный вид графика приведен ниже</p>
# <img src="img/fig_tw_comp.png">

# %%
# Ваш код
